# %%
import numpy as np
import os
import matplotlib.pyplot as plt
#import wandb

#from wandb.integration.keras import WandbMetricsLogger

os.environ["KERAS_BACKEND"] = "torch"

#os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import keras
keras.utils.set_random_seed(812)

# %%
#wandb.login()

# %%
#run = wandb.init(
#    dir = "../results/syntheticdata/",
#    project = "indexes_subsequence_lstm"
#)

# %%
#create synthetic multivariate time series random uniform integers
n = 1000
k = 1
data = np.random.randint(1, 6, (k, n)) #k timeseries of length n

data_scenario1 = data.copy()

#select random timewindows of length 5 without overlapping
motif_indexes_scenario1 = []
motif_pattern = [1,1,1,1,1]
p = len(motif_pattern)

# %%
max_interval = n//50
print("Max interval between motif", max_interval)
last_index = 0
while True:
    min_interval = p + 10
    index_interval = np.random.randint(min_interval, p + max_interval)
    if last_index + index_interval + p > n:
        break
    last_index = last_index + index_interval
    motif_indexes_scenario1.append(last_index)

print("Planted motifs:", len(motif_indexes_scenario1))
print(motif_indexes_scenario1)
for i in motif_indexes_scenario1:
    for j in range(k):
        data_scenario1[j, i:i+p] = motif_pattern
#save to file as csv
data_scenario1 = data_scenario1.astype(int)
np.savetxt("../data/syntheticdata/scenario1.csv", data_scenario1, delimiter=",")
np.savetxt("../data/syntheticdata/motif_indexes_scenario1.csv", motif_indexes_scenario1, delimiter=",")
# Out:
# Max interval between motif 20
# Planted motifs: 51
# [24, 43, 67, 86, 109, 132, 147, 166, 185, 206, 221, 242, 257, 277, 300, 322, 346, 367, 391, 409, 430, 447, 469, 487, 511, 526, 544, 562, 580, 598, 613, 629, 649, 668, 686, 703, 721, 745, 767, 785, 800, 823, 840, 860, 879, 902, 918, 933, 951, 967, 988]

# %%
variable_indexes = np.arange(k)
#change the values of the time series in the selected timewindows to the motif pattern
for idx in motif_indexes_scenario1:
    data_scenario1[variable_indexes,idx:idx+p] = motif_pattern

#introduce hint in the data
for idx in motif_indexes_scenario1:
   data_scenario1[variable_indexes,idx-10:idx-10+3] = [1,2,3]

data_scenario1 = data_scenario1.astype(int)
np.savetxt("../data/syntheticdata/scenario1_withhint.csv", data_scenario1, delimiter=",")

#plot multivariate data using subplots in red the planted motifs
fig, axis = plt.subplots(nrows=k, ncols=1, figsize=(10, 10), sharex=True)
for i, variable in enumerate(variable_indexes):
 plt.subplot(len(variable_indexes), 1, i+1)
 #y axis from 1 to 5
 plt.yticks([1,5])
 plt.plot(data_scenario1[variable], linewidth=0.5)
 #plot the planted motifs
 for idx in motif_indexes_scenario1:
    plt.axvline(x=idx, color='r', linestyle='--', linewidth = 2)

plt.xlabel('Time', size=20)
plt.tight_layout()
plt.savefig("../images/data_scenario1_withhint.pdf")
plt.show()

# %%
from keras.preprocessing.sequence import pad_sequences

def create_dataset(data,variable_indexes, lookback_period, step, forecast_period, motif_indexes):
    X1, X2, y = list(), list(),  list() # X1: data, X2: indexes of the motifs, y: distance to the next motif
    for idx in range(len(data[0]) - lookback_period - 1):
        if idx % step != 0:
            continue

        window_end_idx = idx + lookback_period
        forecast_period__end = window_end_idx + forecast_period

        #if doesnt exist more matches after the window
        if not any([window_end_idx < motif_idx for motif_idx in motif_indexes]):
            break

        motif_indexes_in_window = [motif_idx for motif_idx in motif_indexes if idx <= motif_idx <= window_end_idx]
        motif_indexes_in_forecast_period = [motif_idx for motif_idx in motif_indexes if window_end_idx < motif_idx <= forecast_period__end]

        if motif_indexes_in_forecast_period:
            next_match_in_forecast_period = motif_indexes_in_forecast_period[0]
        else:
            next_match_in_forecast_period = -1  #no match in forward window but exist in the future

        data_window = data[variable_indexes,idx:window_end_idx]

        data_y = -1 
        if next_match_in_forecast_period != -1:
            # index of the next match relative to the last match in the window
            #data_y = next_match_in_forecast_period - motif_indexes_in_window[-1] 
            # index of the next match relative to the end of the window
            data_y = next_match_in_forecast_period - window_end_idx
        
        X1.append(data_window)
        X2.append(motif_indexes_in_window) 
        y.append(data_y) 

    X2 = pad_sequences(X2, padding='post', value=-1, dtype=int)
    return np.array(X1), np.array(X2) , np.array(y)

# %%
#load data
data_scenario1 = np.genfromtxt("../data/syntheticdata/scenario1_withhint.csv", delimiter=",")
data_scenario1 = data_scenario1.astype(int)
motif_indexes_scenario1 = np.genfromtxt("../data/syntheticdata/motif_indexes_scenario1.csv", delimiter=",")
motif_indexes_scenario1= motif_indexes_scenario1.astype(int)

indexes_masking = np.zeros(n)
for motif_index in motif_indexes_scenario1:
    indexes_masking[motif_index:motif_index+p] = 1

data_scenario1_masking = data_scenario1.copy()
data_scenario1_masking = np.vstack((data_scenario1_masking, indexes_masking))

lookback_period = 100 #window size
step = 1 #step size for the sliding window
forecast_period = 50 #forward window size
#x1: past window + masking, x2: indexes of the motif in the window,  y: next relative index of the motif
X1, X2 , y  = create_dataset(data_scenario1_masking,variable_indexes=np.arange(k+1), lookback_period=lookback_period, step=step, forecast_period=forecast_period, motif_indexes=motif_indexes_scenario1)
print(X1.shape, X2.shape, y.shape)
print(X1[0,0], X2[0], y[0])

X1 = np.transpose(X1, (0, 2, 1)) #reshape input to be [samples, time steps, features]
X2 = X2.reshape(X2.shape[0], X2.shape[1], 1) #reshape input to be [samples, time steps, features]
pattern_array = np.tile(motif_pattern, (X1.shape[0], 1)).reshape(X1.shape[0], p, 1)
X1.shape, X2.shape, pattern_array.shape
# Out:
# (888, 2, 100) (888, 6) (888,)
# [4. 1. 1. 4. 2. 4. 1. 5. 3. 4. 5. 1. 1. 4. 1. 2. 3. 3. 3. 4. 2. 3. 2. 4.
#  1. 1. 1. 1. 1. 1. 2. 5. 3. 1. 2. 3. 2. 5. 5. 1. 3. 4. 5. 1. 1. 1. 1. 1.
#  1. 4. 4. 4. 5. 5. 1. 1. 4. 1. 2. 3. 2. 1. 2. 5. 4. 5. 5. 1. 1. 1. 1. 1.
#  4. 2. 1. 1. 1. 2. 3. 2. 5. 3. 2. 4. 1. 3. 1. 1. 1. 1. 1. 5. 4. 5. 1. 5.
#  5. 3. 3. 1.] [24 43 67 86 -1 -1] 9
# ((888, 100, 2), (888, 6, 1), (888, 5, 1))

# %%
class BlockingTimeSeriesSplit():
  def __init__(self, n_splits):
      self.n_splits = n_splits

  def get_n_splits(self, X, y, groups):
      return self.n_splits

  def split(self, X, y=None, groups=None):
      n_samples = len(X)
      k_fold_size = n_samples // self.n_splits
      indices = np.arange(n_samples)

      margin = 0
      for i in range(self.n_splits):
          start = i * k_fold_size
          stop = start + k_fold_size
          mid = int(0.8 * (stop - start)) + start
          yield indices[start: mid], indices[mid + margin: stop]

# %%
#train lstm
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, Masking
from keras import Input

import keras_tuner as kt

class MyHyperModel_LSTM(kt.HyperModel):

    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = Sequential()
        model.add(Input(shape=self.input_shape))
        units = hp.Choice('units', values=[10,25,50,75,100])
        model.add(LSTM(units=units, activation='tanh', return_sequences=False))
        model.add(Dense(1))
        hp_learning_rate = hp.Choice('learning_rate', values=[1e-3, 1e-4, 1e-5])
        model.compile(loss='mse', optimizer=Adam(learning_rate=hp_learning_rate), metrics=['mae', 'root_mean_squared_error', 'r2_score'])
        return model

# %%
import collections
from keras.callbacks import EarlyStopping
from tqdm.keras import TqdmCallback

import pickle
from sklearn.preprocessing import MinMaxScaler

class CVTuner(kt.engine.tuner.Tuner):

    def __init__(self, *args, **kwargs):
        super(CVTuner, self).__init__(*args, **kwargs)
        # cols are metrics-val_loss, val_mae, val_rmse, val_r2
        self.metrics_history = []
        #if exists load metrics history
        if os.path.exists(os.path.join(self.project_dir, "metrics_history.npy")):
            self.metrics_history = np.load(os.path.join(self.project_dir, "metrics_history.npy"), allow_pickle=True)
        

    def run_trial(self, trial, x, y, *args, **kwargs):
        callbacks = kwargs.pop("callbacks", [])
        callbacks.append(EarlyStopping(patience=10, monitor="val_loss", start_from_epoch = 100))
        verbose = kwargs.pop("verbose", 0)
        batch_size = trial.hyperparameters.Choice('batch_size', values=[8,16,32])

        metrics = collections.defaultdict(list)
        cv = BlockingTimeSeriesSplit(n_splits=5)
        trial_metrics = np.zeros((5, 4), dtype=np.float32)

        for i, (train_indices, test_indices) in enumerate(cv.split(y)):
            #split train indices into train and validation
            mid = int(0.8 * len(train_indices))
            train_indices, val_indices = train_indices[:mid], train_indices[mid:]

            #if x is list
            if isinstance(x, list):
                X_train = [x_in[train_indices] for x_in in x]
                X_val = [x_in[val_indices] for x_in in x]
                X_test = [x_in[test_indices] for x_in in x]
            else:
                X_train, X_val, X_test = x[train_indices], x[val_indices], x[test_indices]
            y_train, y_val, y_test = y[train_indices], y[val_indices], y[test_indices]

            model = self.hypermodel.build(trial.hyperparameters)
            model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=400, batch_size=batch_size, verbose=verbose, callbacks=callbacks)
            test_loss, test_mae, test_rmse, test_r2 = model.evaluate(X_test, y_test) 
            metrics["test_loss"].append(test_loss)
            metrics["test_mae"].append(test_mae)
            metrics["test_rmse"].append(test_rmse)
            metrics["test_r2"].append(test_r2)

            trial_metrics[i] = [test_loss, test_mae, test_rmse, test_r2]
                
        self.save_trial_metrics(trial.trial_id, trial_metrics)
        self.metrics_history.append(trial_metrics)
        print({name: np.mean(values) for name, values in metrics.items()})
        #save cross validation metrics
        return {name: np.mean(values) for name, values in metrics.items()}

    def save_trial_metrics(self, trial_id, metrics):
        fname = os.path.join(self.get_trial_dir(trial_id), "metrics.pickle")
        with open(fname, "wb") as f:
            pickle.dump(metrics, f)

    def save_metrics(self):
        # aggregate metric_history into a matrix (num trials, num folds, num metrics)
        fname = os.path.join(self.project_dir, "metrics_history.npy")
        np.save(fname, np.array(self.metrics_history))
    
    def save_model(self, trial_id, model, step=0):
        fname = os.path.join(self.get_trial_dir(trial_id), "model.pickle")
        with open(fname, "wb") as f:
            pickle.dump(model, f)

    def load_model(self, trial):
        fname = os.path.join(self.get_trial_dir(trial.trial_id), "model.pickle")
        with open(fname, "rb") as f:
            return pickle.load(f)

# %%
tuner = CVTuner(
  hypermodel=MyHyperModel_LSTM(input_shape=(X1.shape[1], X1.shape[2])),
  oracle=kt.oracles.GridSearchOracle(
    objective=kt.Objective("test_loss", "min"),
    max_trials=None),
    directory='../results/syntheticdata',
    project_name='scenario1_lstm')
    

X1_normalized = X1.copy()
scalers = []
for i in range(X1.shape[2]-1):
    scaler = MinMaxScaler()
    X1_normalized[:,:,i] = scaler.fit_transform(X1[:,:,i])
    scalers.append(scaler)

tuner.search(
        x=X1_normalized,
        y=y,
        verbose=0,
        callbacks=[TqdmCallback(verbose=0)],
    )
#run.finish()
tuner.save_metrics()
# Out:
# 0epoch [00:00, ?epoch/s]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 18.3004 - mae: 3.2401 - r2_score: 0.3632 - root_mean_squared_error: 4.2769
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 31.2111 - mae: 4.7762 - r2_score: 0.1127 - root_mean_squared_error: 5.5864
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 27.7059 - mae: 4.4758 - r2_score: -0.1056 - root_mean_squared_error: 5.2554
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 35.7993 - mae: 4.8969 - r2_score: 0.0579 - root_mean_squared_error: 5.9825
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 20.1667 - mae: 3.3565 - r2_score: 0.3557 - root_mean_squared_error: 4.4892
# {'test_loss': 27.09285774230957, 'test_mae': 4.19157395362854, 'test_rmse': 5.161361789703369, 'test_r2': 0.1745587706565857}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 28.8287 - mae: 4.5484 - r2_score: -0.0037 - root_mean_squared_error: 5.3685
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 36.1388 - mae: 5.1072 - r2_score: -0.0256 - root_mean_squared_error: 6.0113
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 25.2581 - mae: 4.3153 - r2_score: -0.0041 - root_mean_squared_error: 5.0139
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 38.0927 - mae: 5.0677 - r2_score: -0.0023 - root_mean_squared_error: 6.1709
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 33.1901 - mae: 4.8426 - r2_score: -0.0605 - root_mean_squared_error: 5.7602
# {'test_loss': 33.03249282836914, 'test_mae': 4.854557037353516, 'test_rmse': 5.7354686737060545, 'test_r2': -0.009494161605834961}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32.5451 - mae: 4.7603 - r2_score: -0.1353 - root_mean_squared_error: 5.7048
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37.4277 - mae: 5.0047 - r2_score: -0.0595 - root_mean_squared_error: 6.1138
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26.6053 - mae: 4.3308 - r2_score: -0.0564 - root_mean_squared_error: 5.1444
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 40.9953 - mae: 5.0990 - r2_score: -0.0776 - root_mean_squared_error: 6.3992
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38.8972 - mae: 5.1951 - r2_score: -0.2427 - root_mean_squared_error: 6.2349
# {'test_loss': 36.27006492614746, 'test_mae': 4.959539985656738, 'test_rmse': 6.008521366119385, 'test_r2': -0.10833196640014649}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 54.1311 - mae: 5.9630 - r2_score: -0.8920 - root_mean_squared_error: 7.3550
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 69.5988 - mae: 6.5354 - r2_score: -0.9683 - root_mean_squared_error: 8.3333
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 47.4828 - mae: 5.4469 - r2_score: -0.8983 - root_mean_squared_error: 6.8823
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 66.8716 - mae: 6.3053 - r2_score: -0.7564 - root_mean_squared_error: 8.1695
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 66.5323 - mae: 6.7136 - r2_score: -1.1254 - root_mean_squared_error: 8.1538
# {'test_loss': 62.40858764648438, 'test_mae': 6.255636215209961, 'test_rmse': 7.876458263397216, 'test_r2': -0.9038854837417603}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 75.1572 - mae: 7.1280 - r2_score: -1.6274 - root_mean_squared_error: 8.6660
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 84.7275 - mae: 7.3226 - r2_score: -1.3966 - root_mean_squared_error: 9.1953
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 63.2718 - mae: 6.3584 - r2_score: -1.5367 - root_mean_squared_error: 7.9480
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 103.5794 - mae: 8.2173 - r2_score: -1.7215 - root_mean_squared_error: 10.1697
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 97.2053 - mae: 8.2709 - r2_score: -2.1055 - root_mean_squared_error: 9.8563
# {'test_loss': 86.41534576416015, 'test_mae': 7.510150718688965, 'test_rmse': 9.259197998046876, 'test_r2': -1.6311471939086915}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 101.0984 - mae: 8.4775 - r2_score: -2.5342 - root_mean_squared_error: 10.0511
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 115.7159 - mae: 8.9426 - r2_score: -2.2744 - root_mean_squared_error: 10.7481
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 84.9886 - mae: 7.7532 - r2_score: -2.4154 - root_mean_squared_error: 9.2141
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 106.0791 - mae: 8.3371 - r2_score: -1.7871 - root_mean_squared_error: 10.2914
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 113.1647 - mae: 9.0800 - r2_score: -2.6155 - root_mean_squared_error: 10.6350
# {'test_loss': 105.92590789794922, 'test_mae': 8.562897491455079, 'test_rmse': 10.276088905334472, 'test_r2': -2.2507352352142336}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 113.5895 - mae: 9.2496 - r2_score: -2.9705 - root_mean_squared_error: 10.6542
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 127.9706 - mae: 9.6580 - r2_score: -2.6223 - root_mean_squared_error: 11.3046
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 90.5045 - mae: 8.1054 - r2_score: -2.6379 - root_mean_squared_error: 9.5087
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.3840 - mae: 9.5900 - r2_score: -2.4262 - root_mean_squared_error: 11.4107
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.9488 - mae: 10.2110 - r2_score: -3.3435 - root_mean_squared_error: 11.6569
# {'test_loss': 121.4593292236328, 'test_mae': 9.409273147583008, 'test_rmse': 10.99334487915039, 'test_r2': -2.714741659164429}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 116.5853 - mae: 9.3662 - r2_score: -3.0752 - root_mean_squared_error: 10.7937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 129.9029 - mae: 9.7058 - r2_score: -2.6765 - root_mean_squared_error: 11.3888
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 94.6033 - mae: 8.3455 - r2_score: -2.8043 - root_mean_squared_error: 9.7221
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.7849 - mae: 9.6490 - r2_score: -2.4370 - root_mean_squared_error: 11.4287
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.5303 - mae: 10.2522 - r2_score: -3.3302 - root_mean_squared_error: 11.6391
# {'test_loss': 123.29974822998047, 'test_mae': 9.51077766418457, 'test_rmse': 11.081422233581543, 'test_r2': -2.775648307800293}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 116.7341 - mae: 9.4304 - r2_score: -3.0803 - root_mean_squared_error: 10.8007
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.2187 - mae: 9.9641 - r2_score: -2.8272 - root_mean_squared_error: 11.6199
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 95.5949 - mae: 8.4031 - r2_score: -2.8436 - root_mean_squared_error: 9.7727
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.9852 - mae: 9.8881 - r2_score: -2.5736 - root_mean_squared_error: 11.6536
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 141.3116 - mae: 10.4417 - r2_score: -3.5149 - root_mean_squared_error: 11.8846
# {'test_loss': 126.85102081298828, 'test_mae': 9.6737886428833, 'test_rmse': 11.234493255615234, 'test_r2': -2.878679323196411}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 21.0101 - mae: 3.6303 - r2_score: 0.2683 - root_mean_squared_error: 4.5833
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 34.8032 - mae: 5.0967 - r2_score: 0.0102 - root_mean_squared_error: 5.8987
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 19.1840 - mae: 3.7458 - r2_score: 0.2355 - root_mean_squared_error: 4.3720
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.1489 - mae: 3.5708 - r2_score: 0.3368 - root_mean_squared_error: 5.0144
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 19.9420 - mae: 3.4087 - r2_score: 0.3629 - root_mean_squared_error: 4.4643
# {'test_loss': 24.02851104736328, 'test_mae': 3.894833469390869, 'test_rmse': 4.874725437164306, 'test_r2': 0.26729545593261717}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.3751 - mae: 4.4224 - r2_score: 0.0478 - root_mean_squared_error: 5.2303
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.3787 - mae: 5.4489 - r2_score: -0.1475 - root_mean_squared_error: 6.3543
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.8579 - mae: 4.2836 - r2_score: -0.0303 - root_mean_squared_error: 5.0756
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.0421 - mae: 4.9273 - r2_score: 0.0514 - root_mean_squared_error: 6.0029
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.1296 - mae: 3.7363 - r2_score: 0.1972 - root_mean_squared_error: 5.0112
# {'test_loss': 31.472746276855467, 'test_mae': 4.618778419494629, 'test_rmse': 5.585607719421387, 'test_r2': 0.041010379791259766}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.2214 - mae: 4.4973 - r2_score: 0.0183 - root_mean_squared_error: 5.3106
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.3363 - mae: 5.4448 - r2_score: -0.1463 - root_mean_squared_error: 6.3509
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.8776 - mae: 4.4864 - r2_score: -0.1126 - root_mean_squared_error: 5.2718
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.8537 - mae: 5.0958 - r2_score: 0.0035 - root_mean_squared_error: 6.1521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.1595 - mae: 4.7069 - r2_score: 0.0042 - root_mean_squared_error: 5.5818
# {'test_loss': 33.678047561645506, 'test_mae': 4.918126583099365, 'test_rmse': 5.790277481079102, 'test_r2': -0.029696762561798096}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 29.1934 - mae: 4.5679 - r2_score: -0.0169 - root_mean_squared_error: 5.4027
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.2591 - mae: 4.9678 - r2_score: -0.0269 - root_mean_squared_error: 6.0185
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.1910 - mae: 4.2775 - r2_score: -4.7487e-04 - root_mean_squared_error: 5.0061
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.8454 - mae: 5.0773 - r2_score: -0.0476 - root_mean_squared_error: 6.3095
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.8543 - mae: 4.8901 - r2_score: -0.0817 - root_mean_squared_error: 5.8174
# {'test_loss': 33.93216133117676, 'test_mae': 4.854583740234375, 'test_rmse': 5.808703327178955, 'test_r2': -0.03414719104766846}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.2103 - mae: 5.1741 - r2_score: -0.4045 - root_mean_squared_error: 6.3401
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.0156 - mae: 5.1017 - r2_score: -0.1322 - root_mean_squared_error: 6.3203
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 29.0822 - mae: 4.4678 - r2_score: -0.1558 - root_mean_squared_error: 5.3798
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 55.4193 - mae: 5.7463 - r2_score: -0.4556 - root_mean_squared_error: 7.4373
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 43.5199 - mae: 5.4597 - r2_score: -0.3903 - root_mean_squared_error: 6.5947
# {'test_loss': 42.809454345703124, 'test_mae': 5.2669703483581545, 'test_rmse': 6.509907054901123, 'test_r2': -0.2995136022567749}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 52.6464 - mae: 5.8819 - r2_score: -0.8400 - root_mean_squared_error: 7.2535
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 58.8692 - mae: 5.9869 - r2_score: -0.6647 - root_mean_squared_error: 7.6636
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.4029 - mae: 4.6843 - r2_score: -0.3297 - root_mean_squared_error: 5.7677
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 70.0738 - mae: 6.4570 - r2_score: -0.8405 - root_mean_squared_error: 8.3630
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 50.9365 - mae: 5.8709 - r2_score: -0.6272 - root_mean_squared_error: 7.1343
# {'test_loss': 54.64997253417969, 'test_mae': 5.847846984863281, 'test_rmse': 7.339994430541992, 'test_r2': -0.6483295202255249}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 112.6443 - mae: 9.1595 - r2_score: -2.9375 - root_mean_squared_error: 10.6097
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 117.9026 - mae: 9.0691 - r2_score: -2.3363 - root_mean_squared_error: 10.8493
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 82.5148 - mae: 7.5707 - r2_score: -2.3151 - root_mean_squared_error: 9.0788
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 127.4902 - mae: 9.4663 - r2_score: -2.3502 - root_mean_squared_error: 11.2835
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 115.2455 - mae: 9.1764 - r2_score: -2.6819 - root_mean_squared_error: 10.7324
# {'test_loss': 112.95036468505859, 'test_mae': 8.934671974182129, 'test_rmse': 10.599358940124512, 'test_r2': -2.447398138046265}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 114.7706 - mae: 9.2664 - r2_score: -3.0119 - root_mean_squared_error: 10.7093
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 126.6040 - mae: 9.5524 - r2_score: -2.5831 - root_mean_squared_error: 11.2433
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 88.5326 - mae: 7.9656 - r2_score: -2.5584 - root_mean_squared_error: 9.4045
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.9325 - mae: 9.6438 - r2_score: -2.4408 - root_mean_squared_error: 11.4350
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 134.3507 - mae: 10.1496 - r2_score: -3.2925 - root_mean_squared_error: 11.5882
# {'test_loss': 120.82337951660156, 'test_mae': 9.36154727935791, 'test_rmse': 10.963195037841796, 'test_r2': -2.6934679985046386}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 113.0950 - mae: 9.1877 - r2_score: -2.9533 - root_mean_squared_error: 10.6309
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.2442 - mae: 9.7433 - r2_score: -2.6863 - root_mean_squared_error: 11.4041
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 88.2358 - mae: 7.9514 - r2_score: -2.5471 - root_mean_squared_error: 9.3889
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 131.3814 - mae: 9.6588 - r2_score: -2.4525 - root_mean_squared_error: 11.4545
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.8624 - mae: 10.2144 - r2_score: -3.3408 - root_mean_squared_error: 11.6532
# {'test_loss': 121.55960083007812, 'test_mae': 9.39649829864502, 'test_rmse': 10.992774200439452, 'test_r2': -2.712228536605835}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 19.8217 - mae: 3.5564 - r2_score: 0.3095 - root_mean_squared_error: 4.4519
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 32.0671 - mae: 4.3106 - r2_score: 0.0872 - root_mean_squared_error: 5.6611
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.5252 - mae: 4.3726 - r2_score: 0.0625 - root_mean_squared_error: 4.8414
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.8661 - mae: 4.0716 - r2_score: 0.2914 - root_mean_squared_error: 5.1826
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 18.2888 - mae: 3.1317 - r2_score: 0.4157 - root_mean_squared_error: 4.2751
# {'test_loss': 24.082085037231444, 'test_mae': 3.878827619552612, 'test_rmse': 4.883246994018554, 'test_r2': 0.26136261224746704}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 21.1551 - mae: 3.2722 - r2_score: 0.2628 - root_mean_squared_error: 4.5994
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.1519 - mae: 4.7817 - r2_score: 0.1135 - root_mean_squared_error: 5.5800
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.1671 - mae: 4.6041 - r2_score: -0.0427 - root_mean_squared_error: 5.1059
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.6674 - mae: 4.4674 - r2_score: 0.1126 - root_mean_squared_error: 5.8023
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 21.5274 - mae: 3.7381 - r2_score: 0.3121 - root_mean_squared_error: 4.6392
# {'test_loss': 26.86263084411621, 'test_mae': 4.186417961120606, 'test_rmse': 5.160840129852295, 'test_r2': 0.17769930362701417}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.4290 - mae: 4.1481 - r2_score: 0.1505 - root_mean_squared_error: 4.9404
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.1180 - mae: 5.4258 - r2_score: -0.1401 - root_mean_squared_error: 6.3337
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.0724 - mae: 4.2875 - r2_score: -0.0392 - root_mean_squared_error: 5.0970
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.8113 - mae: 4.9218 - r2_score: 0.0574 - root_mean_squared_error: 5.9837
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.1362 - mae: 3.9233 - r2_score: 0.1969 - root_mean_squared_error: 5.0125
# {'test_loss': 30.848203659057617, 'test_mae': 4.603990840911865, 'test_rmse': 5.527248954772949, 'test_r2': 0.061216211318969725}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.2343 - mae: 4.5007 - r2_score: 0.0179 - root_mean_squared_error: 5.3118
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.0079 - mae: 5.3530 - r2_score: -0.1082 - root_mean_squared_error: 6.2456
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.4712 - mae: 4.4534 - r2_score: -0.0960 - root_mean_squared_error: 5.2329
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.9868 - mae: 5.0962 - r2_score: 1.0316e-04 - root_mean_squared_error: 6.1628
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.2080 - mae: 4.7133 - r2_score: 0.0027 - root_mean_squared_error: 5.5861
# {'test_loss': 33.430415344238284, 'test_mae': 4.899816989898682, 'test_rmse': 5.769753932952881, 'test_r2': -0.022188472747802734}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.8502 - mae: 4.5575 - r2_score: -0.0036 - root_mean_squared_error: 5.3695
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.4091 - mae: 4.9913 - r2_score: -0.0037 - root_mean_squared_error: 5.9492
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.3597 - mae: 4.3940 - r2_score: -0.0502 - root_mean_squared_error: 5.1245
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.2748 - mae: 5.0743 - r2_score: -0.0070 - root_mean_squared_error: 6.1855
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.6517 - mae: 4.8761 - r2_score: -0.0752 - root_mean_squared_error: 5.8001
# {'test_loss': 33.409237670898435, 'test_mae': 4.869904804229736, 'test_rmse': 5.769743347167969, 'test_r2': -0.022251653671264648}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 29.1314 - mae: 4.5603 - r2_score: -0.0147 - root_mean_squared_error: 5.3970
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.5103 - mae: 5.0818 - r2_score: -0.1180 - root_mean_squared_error: 6.2805
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.2277 - mae: 4.2748 - r2_score: -0.0017 - root_mean_squared_error: 5.0094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 42.6449 - mae: 5.1732 - r2_score: -0.1207 - root_mean_squared_error: 6.5262
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.8810 - mae: 5.0027 - r2_score: -0.1464 - root_mean_squared_error: 5.9887
# {'test_loss': 35.72271728515625, 'test_mae': 4.9240082740783695, 'test_rmse': 5.951035976409912, 'test_r2': -0.08392565250396729}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 60.6153 - mae: 6.3280 - r2_score: -1.1189 - root_mean_squared_error: 7.7828
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 60.4366 - mae: 6.0615 - r2_score: -0.7090 - root_mean_squared_error: 7.7649
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.0931 - mae: 4.8093 - r2_score: -0.4380 - root_mean_squared_error: 5.9965
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 75.4556 - mae: 6.7164 - r2_score: -0.9820 - root_mean_squared_error: 8.6784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 76.1080 - mae: 7.2131 - r2_score: -1.4314 - root_mean_squared_error: 8.7210
# {'test_loss': 63.04582901000977, 'test_mae': 6.286823081970215, 'test_rmse': 7.885621833801269, 'test_r2': -0.9143240690231323}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 112.6966 - mae: 9.1445 - r2_score: -2.9394 - root_mean_squared_error: 10.6121
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 115.6233 - mae: 8.9703 - r2_score: -2.2720 - root_mean_squared_error: 10.7441
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 82.4654 - mae: 7.5546 - r2_score: -2.3138 - root_mean_squared_error: 9.0763
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 129.2711 - mae: 9.5431 - r2_score: -2.3971 - root_mean_squared_error: 11.3621
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 128.1574 - mae: 9.8235 - r2_score: -3.0945 - root_mean_squared_error: 11.3178
# {'test_loss': 115.33768615722656, 'test_mae': 9.051838493347168, 'test_rmse': 10.708604049682616, 'test_r2': -2.524115228652954}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 114.6310 - mae: 9.2603 - r2_score: -3.0070 - root_mean_squared_error: 10.7028
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 129.3137 - mae: 9.6729 - r2_score: -2.6596 - root_mean_squared_error: 11.3628
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 91.0062 - mae: 8.1313 - r2_score: -2.6587 - root_mean_squared_error: 9.5352
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 133.9846 - mae: 9.7913 - r2_score: -2.5211 - root_mean_squared_error: 11.5676
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 135.9610 - mae: 10.2302 - r2_score: -3.3439 - root_mean_squared_error: 11.6575
# {'test_loss': 122.82715759277343, 'test_mae': 9.464422798156738, 'test_rmse': 11.053395843505859, 'test_r2': -2.7530730247497557}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 19.6137 - mae: 3.3396 - r2_score: 0.3191 - root_mean_squared_error: 4.4238
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.1896 - mae: 4.4756 - r2_score: 0.2259 - root_mean_squared_error: 5.2125
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.9304 - mae: 4.3459 - r2_score: 0.0050 - root_mean_squared_error: 4.9854
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 22.0540 - mae: 3.6542 - r2_score: 0.4184 - root_mean_squared_error: 4.6957
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 22.4596 - mae: 3.3985 - r2_score: 0.2825 - root_mean_squared_error: 4.7375
# {'test_loss': 23.42417793273926, 'test_mae': 3.833777904510498, 'test_rmse': 4.832928943634033, 'test_r2': 0.270627498626709}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20.5587 - mae: 3.4767 - r2_score: 0.2841 - root_mean_squared_error: 4.5337
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.7782 - mae: 4.5121 - r2_score: 0.0388 - root_mean_squared_error: 5.8106
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.7549 - mae: 4.5915 - r2_score: -0.0270 - root_mean_squared_error: 5.0663
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 30.0176 - mae: 4.1500 - r2_score: 0.2081 - root_mean_squared_error: 5.4780
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.8185 - mae: 3.9093 - r2_score: 0.0794 - root_mean_squared_error: 5.3662
# {'test_loss': 27.697520446777343, 'test_mae': 4.109892320632935, 'test_rmse': 5.2496137619018555, 'test_r2': 0.1483566403388977}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20.6754 - mae: 3.7836 - r2_score: 0.2806 - root_mean_squared_error: 4.5459
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.8719 - mae: 5.2360 - r2_score: -0.0764 - root_mean_squared_error: 6.1538
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.5196 - mae: 4.1962 - r2_score: 0.0238 - root_mean_squared_error: 4.9417
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.8834 - mae: 4.2174 - r2_score: 0.2653 - root_mean_squared_error: 5.2805
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.1591 - mae: 3.6228 - r2_score: 0.1643 - root_mean_squared_error: 5.1127
# {'test_loss': 27.682225036621094, 'test_mae': 4.247386121749878, 'test_rmse': 5.238185787200928, 'test_r2': 0.15227620601654052}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.3675 - mae: 4.4261 - r2_score: 0.0480 - root_mean_squared_error: 5.2297
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.7713 - mae: 5.4022 - r2_score: -0.1302 - root_mean_squared_error: 6.3063
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.7860 - mae: 4.3927 - r2_score: -0.0680 - root_mean_squared_error: 5.1667
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.8704 - mae: 5.0089 - r2_score: 0.0294 - root_mean_squared_error: 6.0717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 30.3814 - mae: 4.6271 - r2_score: 0.0291 - root_mean_squared_error: 5.5116
# {'test_loss': 32.81064720153809, 'test_mae': 4.84208459854126, 'test_rmse': 5.713948535919189, 'test_r2': -0.002444911003112793}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.7506 - mae: 4.5425 - r2_score: 4.7644e-05 - root_mean_squared_error: 5.3599
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.5300 - mae: 5.3862 - r2_score: -0.1232 - root_mean_squared_error: 6.2872
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.2027 - mae: 4.4338 - r2_score: -0.0849 - root_mean_squared_error: 5.2069
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.0053 - mae: 5.1061 - r2_score: -4.4636e-04 - root_mean_squared_error: 6.1644
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.0430 - mae: 4.6955 - r2_score: 0.0079 - root_mean_squared_error: 5.5713
# {'test_loss': 33.54638938903808, 'test_mae': 4.908421993255615, 'test_rmse': 5.779522514343261, 'test_r2': -0.025540089607238768}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.9075 - mae: 4.5653 - r2_score: -0.0057 - root_mean_squared_error: 5.3749
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.2015 - mae: 5.1136 - r2_score: -0.0274 - root_mean_squared_error: 6.0166
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.0199 - mae: 4.4394 - r2_score: -0.0773 - root_mean_squared_error: 5.1891
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.0381 - mae: 5.0748 - r2_score: -9.8825e-04 - root_mean_squared_error: 6.1667
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.5873 - mae: 4.7485 - r2_score: -0.0094 - root_mean_squared_error: 5.6199
# {'test_loss': 33.13855743408203, 'test_mae': 4.874896144866943, 'test_rmse': 5.74690351486206, 'test_r2': -0.014440047740936279}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.5380 - mae: 5.1344 - r2_score: -0.3809 - root_mean_squared_error: 6.2869
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 44.5131 - mae: 5.2967 - r2_score: -0.2590 - root_mean_squared_error: 6.6647
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.3948 - mae: 4.3720 - r2_score: -0.0879 - root_mean_squared_error: 5.2204
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 47.7684 - mae: 5.3783 - r2_score: -0.2549 - root_mean_squared_error: 6.9056
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 44.5205 - mae: 5.5166 - r2_score: -0.4223 - root_mean_squared_error: 6.6700
# {'test_loss': 41.87490234375, 'test_mae': 5.217444229125976, 'test_rmse': 6.446115112304687, 'test_r2': -0.27388653755187986}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 64.8596 - mae: 6.5637 - r2_score: -1.2673 - root_mean_squared_error: 8.0506
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 74.2447 - mae: 6.7674 - r2_score: -1.0997 - root_mean_squared_error: 8.6069
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 48.0790 - mae: 5.4704 - r2_score: -0.9221 - root_mean_squared_error: 6.9254
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 69.2958 - mae: 6.4113 - r2_score: -0.8201 - root_mean_squared_error: 8.3164
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 85.3982 - mae: 7.6870 - r2_score: -1.7282 - root_mean_squared_error: 9.2381
# {'test_loss': 69.72846908569336, 'test_mae': 6.635746765136719, 'test_rmse': 8.320792961120606, 'test_r2': -1.1352767944335938}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 113.7279 - mae: 9.2187 - r2_score: -2.9754 - root_mean_squared_error: 10.6606
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 124.9616 - mae: 9.4709 - r2_score: -2.5365 - root_mean_squared_error: 11.1700
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 87.9240 - mae: 7.9271 - r2_score: -2.5344 - root_mean_squared_error: 9.3722
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 131.5549 - mae: 9.6603 - r2_score: -2.4570 - root_mean_squared_error: 11.4620
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 135.0345 - mae: 10.1810 - r2_score: -3.3143 - root_mean_squared_error: 11.6177
# {'test_loss': 120.42545623779297, 'test_mae': 9.338021278381348, 'test_rmse': 10.943792915344238, 'test_r2': -2.680449199676514}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 18.3310 - mae: 3.3634 - r2_score: 0.3621 - root_mean_squared_error: 4.2805
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26.7221 - mae: 3.7770 - r2_score: 0.2393 - root_mean_squared_error: 5.1676
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 21.0795 - mae: 3.9649 - r2_score: 0.1578 - root_mean_squared_error: 4.5851
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 73.9414 - mae: 7.1138 - r2_score: -0.9399 - root_mean_squared_error: 8.5831
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 27.1498 - mae: 3.7543 - r2_score: 0.1327 - root_mean_squared_error: 5.2085
# {'test_loss': 34.67664794921875, 'test_mae': 4.437837553024292, 'test_rmse': 5.645166492462158, 'test_r2': -0.011827170848846436}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 23.2486 - mae: 3.9092 - r2_score: 0.1910 - root_mean_squared_error: 4.8205
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 36.8907 - mae: 4.6350 - r2_score: -0.0489 - root_mean_squared_error: 6.0733
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 21.7684 - mae: 3.9528 - r2_score: 0.1328 - root_mean_squared_error: 4.6568
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 29.2919 - mae: 4.5014 - r2_score: 0.2274 - root_mean_squared_error: 5.4115
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 30.3238 - mae: 3.8649 - r2_score: 0.0313 - root_mean_squared_error: 5.5046
# {'test_loss': 28.30832710266113, 'test_mae': 4.164862871170044, 'test_rmse': 5.303861045837403, 'test_r2': 0.13360037803649902}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 25.1432 - mae: 4.0447 - r2_score: 0.1249 - root_mean_squared_error: 5.0133
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 37.7570 - mae: 5.3393 - r2_score: -0.0745 - root_mean_squared_error: 6.1431
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 24.9698 - mae: 4.4476 - r2_score: 0.0064 - root_mean_squared_error: 4.9863
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26.8336 - mae: 4.4527 - r2_score: 0.2921 - root_mean_squared_error: 5.1793
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26.5474 - mae: 3.6370 - r2_score: 0.1519 - root_mean_squared_error: 5.1505
# {'test_loss': 28.254314804077147, 'test_mae': 4.366191434860229, 'test_rmse': 5.30215482711792, 'test_r2': 0.12898870706558227}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27.0170 - mae: 3.9789 - r2_score: 0.0590 - root_mean_squared_error: 5.1974
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 38.4627 - mae: 5.3115 - r2_score: -0.0930 - root_mean_squared_error: 6.2017
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 33.7934 - mae: 5.2419 - r2_score: -0.3499 - root_mean_squared_error: 5.8053
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 38.5088 - mae: 5.1728 - r2_score: -0.0151 - root_mean_squared_error: 6.2053
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 25.8193 - mae: 3.9187 - r2_score: 0.1751 - root_mean_squared_error: 5.0797
# {'test_loss': 32.95618362426758, 'test_mae': 4.752604055404663, 'test_rmse': 5.718786811828613, 'test_r2': -0.013142549991607666}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.9560 - mae: 4.4764 - r2_score: 0.0276 - root_mean_squared_error: 5.2854
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.2796 - mae: 5.4406 - r2_score: -0.1447 - root_mean_squared_error: 6.3465
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 26.6775 - mae: 4.3820 - r2_score: -0.0635 - root_mean_squared_error: 5.1560
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.5369 - mae: 5.0688 - r2_score: 0.0119 - root_mean_squared_error: 6.1263
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 30.9113 - mae: 4.6827 - r2_score: 0.0122 - root_mean_squared_error: 5.5595
# {'test_loss': 33.26751441955567, 'test_mae': 4.88210096359253, 'test_rmse': 5.753359317779541, 'test_r2': -0.015935945510864257}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 28.6678 - mae: 4.5359 - r2_score: 0.0029 - root_mean_squared_error: 5.3523
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.8675 - mae: 5.3415 - r2_score: -0.1042 - root_mean_squared_error: 6.2344
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27.8052 - mae: 4.4801 - r2_score: -0.1096 - root_mean_squared_error: 5.2649
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.0175 - mae: 5.1133 - r2_score: -8.1499e-04 - root_mean_squared_error: 6.1654
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 30.8828 - mae: 4.6781 - r2_score: 0.0130 - root_mean_squared_error: 5.5570
# {'test_loss': 33.498304748535155, 'test_mae': 4.906653976440429, 'test_rmse': 5.776501655578613, 'test_r2': -0.024972355365753172}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 30.0429 - mae: 4.6053 - r2_score: -0.0472 - root_mean_squared_error: 5.4811
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.6882 - mae: 4.9705 - r2_score: -0.0111 - root_mean_squared_error: 5.9718
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.2995 - mae: 4.2861 - r2_score: -0.0047 - root_mean_squared_error: 5.0167
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.8600 - mae: 5.0883 - r2_score: -0.0480 - root_mean_squared_error: 6.3108
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.7641 - mae: 4.9951 - r2_score: -0.1427 - root_mean_squared_error: 5.9789
# {'test_loss': 34.23900451660156, 'test_mae': 4.8736122131347654, 'test_rmse': 5.8366539001464846, 'test_r2': -0.04510684013366699}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 44.5208 - mae: 5.4180 - r2_score: -0.5555 - root_mean_squared_error: 6.6708
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 47.3261 - mae: 5.4269 - r2_score: -0.3384 - root_mean_squared_error: 6.8717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 31.4861 - mae: 4.5896 - r2_score: -0.2526 - root_mean_squared_error: 5.5989
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 59.7091 - mae: 5.9392 - r2_score: -0.5683 - root_mean_squared_error: 7.7196
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 44.5985 - mae: 5.5253 - r2_score: -0.4248 - root_mean_squared_error: 6.6759
# {'test_loss': 46.848934936523435, 'test_mae': 5.458441352844238, 'test_rmse': 6.8089807510375975, 'test_r2': -0.41919145584106443}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 110.2397 - mae: 9.0289 - r2_score: -2.8535 - root_mean_squared_error: 10.4958
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 123.4199 - mae: 9.3781 - r2_score: -2.4928 - root_mean_squared_error: 11.1007
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 88.1103 - mae: 7.9258 - r2_score: -2.5420 - root_mean_squared_error: 9.3822
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 128.2642 - mae: 9.5084 - r2_score: -2.3707 - root_mean_squared_error: 11.3179
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.5714 - mae: 9.9691 - r2_score: -3.1717 - root_mean_squared_error: 11.4240
# {'test_loss': 117.89720306396484, 'test_mae': 9.208038330078125, 'test_rmse': 10.830907249450684, 'test_r2': -2.6042120456695557}

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ../results/syntheticdata/schenario1_lstm
# Showing 10 best trials
# Objective(name="test_loss", direction="min")
#
# Trial 0027 summary
# Hyperparameters:
# units: 75
# learning_rate: 0.001
# batch_size: 8
# Score: 23.42417793273926
#
# Trial 0009 summary
# Hyperparameters:
# units: 25
# learning_rate: 0.001
# batch_size: 8
# Score: 24.02851104736328
#
# Trial 0018 summary
# Hyperparameters:
# units: 50
# learning_rate: 0.001
# batch_size: 8
# Score: 24.082085037231444
#
# Trial 0019 summary
# Hyperparameters:
# units: 50
# learning_rate: 0.001
# batch_size: 16
# Score: 26.86263084411621
#
# Trial 0000 summary
# Hyperparameters:
# units: 10
# learning_rate: 0.001
# batch_size: 8
# Score: 27.09285774230957
#
# Trial 0029 summary
# Hyperparameters:
# units: 75
# learning_rate: 0.001
# batch_size: 32
# Score: 27.682225036621094
#
# Trial 0028 summary
# Hyperparameters:
# units: 75
# learning_rate: 0.001
# batch_size: 16
# Score: 27.697520446777343
#
# Trial 0038 summary
# Hyperparameters:
# units: 100
# learning_rate: 0.001
# batch_size: 32
# Score: 28.254314804077147
#
# Trial 0037 summary
# Hyperparameters:
# units: 100
# learning_rate: 0.001
# batch_size: 16
# Score: 28.30832710266113
#
# Trial 0020 summary
# Hyperparameters:
# units: 50
# learning_rate: 0.001
# batch_size: 32
# Score: 30.848203659057617

# %%
#get config of the best model
best_trial = tuner.oracle.get_best_trials(1)[0]

print(best_trial.hyperparameters.values)
print(best_trial.metrics.get_best_value("test_mae"))

#load best trial metrics file
cv_metrics = np.load(os.path.join(tuner.get_trial_dir(best_trial.trial_id), "metrics.pickle"), allow_pickle=True)
print(cv_metrics)

metrics = []
#train test split
mid = int(0.8 * len(np.arange(len(X1))))
X_train, X_test = X1[:mid], X1[mid:]
y_train, y_test = y[:mid], y[mid:]
model = MyHyperModel_LSTM(input_shape=(X1.shape[1],X1.shape[2])).build((best_trial.hyperparameters))
history = model.fit(X_train, y_train, validation_data = (X_test, y_test),
          epochs=400, batch_size=best_trial.hyperparameters.values["batch_size"],
          verbose=0, callbacks=[EarlyStopping(patience=10, monitor="val_loss", start_from_epoch = 100),  TqdmCallback(verbose=0)])
metrics.append(model.evaluate(X_test, y_test))

keras.utils.plot_model(model, to_file="../images/best_model_lstm_casestudy_scenario1.png", show_shapes=True)
metrics = np.array(metrics)
print(metrics)
# Out:
# {'units': 75, 'learning_rate': 0.001, 'batch_size': 8}
# 3.833777904510498
# [[20.904808    3.4296257   4.5721774   0.29510522]
#  [26.150904    4.333792    5.1137953   0.28110534]
#  [26.833675    4.4598274   5.1801233   0.02845538]
#  [21.610678    3.6367655   4.648729    0.44494665]
#  [21.620825    3.3088787   4.64982     0.3035249 ]]
# 0epoch [00:00, ?epoch/s]
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 15.2465 - mae: 2.5706 - r2_score: 0.4824 - root_mean_squared_error: 3.8715
# [[18.25537682  3.00723505  4.27263117  0.39997423]]

# %%
import pandas as pd
logs = pd.DataFrame(history.history)

plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(logs["loss"], lw=2, label='training loss')
plt.plot(logs["val_loss"], lw=2, label='validation loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(logs["mae"], lw=2, label='training MAE')
plt.plot(logs["val_mae"], lw=2, label='validation MAE')
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.legend(loc='upper right')
plt.show()

# %%
#plot prediction vs true values
y_pred = model.predict(X_test)

plt.plot(y_test, label="True")
plt.plot(y_pred, label="Predicted")
plt.legend()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
