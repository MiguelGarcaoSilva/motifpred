# %%
import numpy as np
import pandas as pd
import os
import sys
import torch
import csv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import optuna
import random
import joblib
from config import RESULTS_DIR, IMAGES_DIR, DATA_DIR, DATASET_PATH, MOTIF_INDEXES_PATH, K, N, P, NORMALIZE_FLAGS

print(f"Results will be saved in: {RESULTS_DIR}")
print(f"Images will be saved in: {IMAGES_DIR}")
print(f"Data will be accessed from: {DATA_DIR}")

os.makedirs(RESULTS_DIR, exist_ok=True)

if '__file__' in globals():
    # For standalone scripts
    base_dir = os.path.dirname(__file__)
else:
    # For Jupyter or interactive environments
    base_dir = os.getcwd()

# Add the parent directory of `utils` to the Python path
sys.path.append(os.path.abspath(os.path.join(base_dir, "../")))
# Out:
# 2025-01-03 18:37:33,705 - INFO - Results will be saved in: /home/mgsilva/motifpred/results/syntheticdata1/variables=[0,2]
# 2025-01-03 18:37:33,706 - INFO - Images will be saved in: /home/mgsilva/motifpred/images/syntheticdata1/variables=[0,2]
# 2025-01-03 18:37:33,706 - INFO - Data will be accessed from: /home/mgsilva/motifpred/data/syntheticdata1/variables=[0,2]
# Results will be saved in: /home/mgsilva/motifpred/results/syntheticdata1/variables=[0,2]
# Images will be saved in: /home/mgsilva/motifpred/images/syntheticdata1/variables=[0,2]
# Data will be accessed from: /home/mgsilva/motifpred/data/syntheticdata1/variables=[0,2]

# %%
# Import shared setup
from utils.setup import seed, device, early_stopper, pipeline, test_tensor

# Example usage
print(f"Device: {device}")
test_tensor()
# Out:
# Device: cuda
# tensor([[0.3126, 0.3791, 0.3087],
#         [0.0736, 0.4216, 0.0691],
#         [0.2332, 0.4047, 0.2162],
#         [0.9927, 0.4128, 0.5938],
#         [0.6128, 0.1519, 0.0453]])

# %%
data = np.genfromtxt(DATASET_PATH, delimiter=",").astype(int).reshape((K, N))
motif_indexes = np.genfromtxt(MOTIF_INDEXES_PATH, delimiter=",").astype(int)

print(motif_indexes)
# Out:
# [    0    10    22 ... 99922 99956 99992]

# %%
data
# Out:
# array([[1, 1, 1, ..., 3, 5, 3],
#        [4, 3, 1, ..., 2, 4, 1],
#        [3, 3, 3, ..., 5, 2, 3]])

# %%
from utils.timeseries_split import BlockingTimeSeriesSplit

#create index  
indexes = np.arange(len(data[0]))

#split data
tscv = BlockingTimeSeriesSplit(n_splits=5)
# Create the figure
fig, ax = plt.subplots(figsize=(10, 6))
for i, (train_index, test_index) in enumerate(tscv.split(indexes)):
    # Plot train and test indices
    ax.plot(train_index, np.zeros_like(train_index) + i, 'o', color='lightblue')
    ax.plot(test_index, np.zeros_like(test_index) + i, 'o', color='red')
    print("TRAIN:", train_index, "TEST:", test_index)
    

ax.set_yticks(np.arange(5), ["Fold {}".format(i) for i in range(1, 6)])
plt.show()
# Out:
# TRAIN: [    0     1     2 ... 15997 15998 15999] TEST: [16000 16001 16002 ... 19997 19998 19999]
# TRAIN: [20000 20001 20002 ... 35997 35998 35999] TEST: [36000 36001 36002 ... 39997 39998 39999]
# TRAIN: [40000 40001 40002 ... 55997 55998 55999] TEST: [56000 56001 56002 ... 59997 59998 59999]
# TRAIN: [60000 60001 60002 ... 75997 75998 75999] TEST: [76000 76001 76002 ... 79997 79998 79999]
# TRAIN: [80000 80001 80002 ... 95997 95998 95999] TEST: [96000 96001 96002 ... 99997 99998 99999]

# %%
from utils.utils import create_dataset

lookback_period = 100 #window size
step = 5 #step size for the sliding window
forecast_period = 50 #forward window size

#X_series: past window, X_indices: indexes of the motif in the window,  y: next relative index of the motif
X_series, X_indices, y = create_dataset(data, lookback_period, step, forecast_period, motif_indexes)

#X_series is (num_samples, lookback_period, num_features)
X_mask = np.zeros((X_series.shape[0], X_series.shape[1])) 

for i, obs_motif_indexes in enumerate(X_indices):
    for j, idx in enumerate(obs_motif_indexes):
        idx = int(idx)
        X_mask[i, idx:idx+P] = 1

X_mask = torch.tensor(X_mask, dtype=torch.float32)

# X_series, X2, and y are now PyTorch tensors
print("X_series shape:", X_series.shape)  # Expected shape: (num_samples, lookback_period, num_features)
print("X_mask shape:", X_mask.shape)  # Expected shape: (num_samples, lookback_period)
print("X_indices shape:", X_indices.shape)  # Expected shape: (num_samples, max_motif_length_in_window)
print("y shape:", y.shape)    # Expected shape: (num_samples, 1)
# Out:
# X_series shape: torch.Size([19979, 100, 3])
# X_mask shape: torch.Size([19979, 100])
# X_indices shape: torch.Size([19979, 6, 1])
# y shape: torch.Size([19979, 1])

# %%
from models.ffnn_pytorch import FFNN
from utils.train_pipeline import run_optuna_study
from utils.utils import print_study_results, plot_best_model_results

n_trials = 100
num_epochs = 500
model_type = "FFNN"
model_name = "FFNNSeries"

suggestion_dict = {
    "learning_rate": {
        "type": "float",
        "args": [1e-5, 1e-3], 
        "kwargs": {"log": True} 
    },
    "num_layers": {
        "type": "categorical",
        "args": [[1, 2, 3, 4]] 
    },        
    "batch_size": {
        "type": "categorical",
        "args": [[16, 32, 64, 128]] 
    }
}

model_params_keys = ["hidden_sizes_list"]


model_results_dir = os.path.join(RESULTS_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs")
os.makedirs(model_results_dir, exist_ok=True)

X = {"X_series": X_series}
run_optuna_study(pipeline.run_cross_val, FFNN, model_type,suggestion_dict,  model_params_keys, seed, X , y, NORMALIZE_FLAGS, model_results_dir, n_trials=n_trials, num_epochs=num_epochs)

study = joblib.load(os.path.join(model_results_dir, "study.pkl"))
print_study_results(study)
plot_best_model_results(study.trials_dataframe(), save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
# Out:
# [I 2025-01-03 18:40:12,270] A new study created in memory with name: no-name-631355e0-60f0-48c4-84be-50fdf3d32535
# Early stopping at epoch 359, with best epoch being 348
# Training completed all epochs. Best epoch was 499
# Early stopping at epoch 489, with best epoch being 478
# Early stopping at epoch 378, with best epoch being 367
# [I 2025-01-03 18:41:38,722] Trial 0 finished with value: 125.6861572265625 and parameters: {'learning_rate': 2.6565450821928437e-05, 'num_layers': 3, 'batch_size': 128, 'hidden_size_layer_0': 64, 'hidden_size_layer_1': 64, 'hidden_size_layer_2': 16}. Best is trial 0 with value: 125.6861572265625.
# Early stopping at epoch 383, with best epoch being 372
# Early stopping at epoch 114, with best epoch being 19
# Early stopping at epoch 111, with best epoch being 21
# Early stopping at epoch 112, with best epoch being 22
# Early stopping at epoch 117, with best epoch being 18
# [I 2025-01-03 18:43:26,991] Trial 1 finished with value: 125.59446350097656 and parameters: {'learning_rate': 8.234629491061175e-05, 'num_layers': 4, 'batch_size': 32, 'hidden_size_layer_0': 64, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 128, 'hidden_size_layer_3': 256}. Best is trial 1 with value: 125.59446350097656.
# Early stopping at epoch 111, with best epoch being 20
# Early stopping at epoch 144, with best epoch being 6
# Early stopping at epoch 125, with best epoch being 17
# Early stopping at epoch 114, with best epoch being 17
# Early stopping at epoch 112, with best epoch being 5
# [I 2025-01-03 18:45:01,576] Trial 2 finished with value: 124.94793891906738 and parameters: {'learning_rate': 0.00045718845609921366, 'num_layers': 3, 'batch_size': 32, 'hidden_size_layer_0': 128, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 128}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 137, with best epoch being 6
# Early stopping at epoch 136, with best epoch being 125
# Early stopping at epoch 141, with best epoch being 130
# Early stopping at epoch 157, with best epoch being 146
# Early stopping at epoch 129, with best epoch being 118
# [I 2025-01-03 18:46:43,924] Trial 3 finished with value: 125.11998226165773 and parameters: {'learning_rate': 1.898502408249566e-05, 'num_layers': 3, 'batch_size': 32, 'hidden_size_layer_0': 128, 'hidden_size_layer_1': 128, 'hidden_size_layer_2': 64}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 129, with best epoch being 118
# Early stopping at epoch 111, with best epoch being 90
# Early stopping at epoch 120, with best epoch being 109
# Early stopping at epoch 129, with best epoch being 118
# Early stopping at epoch 112, with best epoch being 85
# [I 2025-01-03 18:47:30,993] Trial 4 finished with value: 125.33687438964844 and parameters: {'learning_rate': 0.0001131044970520915, 'num_layers': 1, 'batch_size': 32, 'hidden_size_layer_0': 32}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 112, with best epoch being 92
# Early stopping at epoch 113, with best epoch being 9
# Early stopping at epoch 118, with best epoch being 16
# Early stopping at epoch 112, with best epoch being 47
# Early stopping at epoch 114, with best epoch being 8
# [I 2025-01-03 18:48:49,455] Trial 5 finished with value: 125.52411739349364 and parameters: {'learning_rate': 0.0009804052004436631, 'num_layers': 2, 'batch_size': 32, 'hidden_size_layer_0': 64, 'hidden_size_layer_1': 32}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 112, with best epoch being 9
# Early stopping at epoch 153, with best epoch being 4
# Early stopping at epoch 124, with best epoch being 5
# Early stopping at epoch 132, with best epoch being 15
# Early stopping at epoch 126, with best epoch being 4
# [I 2025-01-03 18:49:56,703] Trial 6 finished with value: 125.27875671386718 and parameters: {'learning_rate': 0.0009458955741323804, 'num_layers': 4, 'batch_size': 64, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 256, 'hidden_size_layer_3': 128}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 111, with best epoch being 4
# Early stopping at epoch 148, with best epoch being 137
# Early stopping at epoch 165, with best epoch being 154
# Early stopping at epoch 133, with best epoch being 122
# Early stopping at epoch 142, with best epoch being 131
# [I 2025-01-03 18:51:25,480] Trial 7 finished with value: 125.37829421997068 and parameters: {'learning_rate': 8.31942132788649e-05, 'num_layers': 2, 'batch_size': 32, 'hidden_size_layer_0': 16, 'hidden_size_layer_1': 16}. Best is trial 2 with value: 124.94793891906738.
# Early stopping at epoch 111, with best epoch being 93
# Early stopping at epoch 111, with best epoch being 15
# Early stopping at epoch 117, with best epoch being 58
# Early stopping at epoch 112, with best epoch being 17
# Early stopping at epoch 116, with best epoch being 15
# [I 2025-01-03 18:52:06,413] Trial 8 finished with value: 124.9380567932129 and parameters: {'learning_rate': 0.0002254875859707374, 'num_layers': 2, 'batch_size': 64, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 256}. Best is trial 8 with value: 124.9380567932129.
# Early stopping at epoch 111, with best epoch being 14
# Early stopping at epoch 115, with best epoch being 20
# Early stopping at epoch 111, with best epoch being 25
# Early stopping at epoch 111, with best epoch being 28
# Early stopping at epoch 114, with best epoch being 21
# [I 2025-01-03 18:52:33,349] Trial 9 finished with value: 125.52241760253905 and parameters: {'learning_rate': 0.0006341376437480116, 'num_layers': 3, 'batch_size': 128, 'hidden_size_layer_0': 64, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 16}. Best is trial 8 with value: 124.9380567932129.
# Early stopping at epoch 113, with best epoch being 28
# Early stopping at epoch 111, with best epoch being 19
# Early stopping at epoch 113, with best epoch being 66
# Early stopping at epoch 112, with best epoch being 73
# Early stopping at epoch 118, with best epoch being 17
# [I 2025-01-03 18:53:10,450] Trial 10 finished with value: 120.72217437744139 and parameters: {'learning_rate': 0.0002302227342309835, 'num_layers': 2, 'batch_size': 64, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 128}. Best is trial 10 with value: 120.72217437744139.
# Early stopping at epoch 111, with best epoch being 78
# Early stopping at epoch 111, with best epoch being 17
# Early stopping at epoch 113, with best epoch being 84
# Early stopping at epoch 112, with best epoch being 67
# Early stopping at epoch 112, with best epoch being 17
# [I 2025-01-03 18:53:44,918] Trial 11 finished with value: 122.58632400512695 and parameters: {'learning_rate': 0.00023783074177952606, 'num_layers': 2, 'batch_size': 64, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 128}. Best is trial 10 with value: 120.72217437744139.
# Early stopping at epoch 116, with best epoch being 17
# Early stopping at epoch 111, with best epoch being 17
# Early stopping at epoch 120, with best epoch being 72
# Early stopping at epoch 113, with best epoch being 67
# Early stopping at epoch 111, with best epoch being 61
# [I 2025-01-03 18:54:14,526] Trial 12 finished with value: 122.62882995605469 and parameters: {'learning_rate': 0.00024643578994967336, 'num_layers': 2, 'batch_size': 64, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 128}. Best is trial 10 with value: 120.72217437744139.
# Early stopping at epoch 114, with best epoch being 82
# Early stopping at epoch 119, with best epoch being 43
# Early stopping at epoch 145, with best epoch being 35
# Early stopping at epoch 121, with best epoch being 33
# Early stopping at epoch 117, with best epoch being 7
# [I 2025-01-03 18:56:22,363] Trial 13 finished with value: 120.6114013671875 and parameters: {'learning_rate': 0.00022196326201312288, 'num_layers': 2, 'batch_size': 16, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 128}. Best is trial 13 with value: 120.6114013671875.
# Early stopping at epoch 116, with best epoch being 44
# Early stopping at epoch 111, with best epoch being 76
# Early stopping at epoch 112, with best epoch being 93
# Early stopping at epoch 114, with best epoch being 91
# Early stopping at epoch 112, with best epoch being 71
# [I 2025-01-03 18:58:30,634] Trial 14 finished with value: 125.23783912658692 and parameters: {'learning_rate': 3.65465513238174e-05, 'num_layers': 1, 'batch_size': 16, 'hidden_size_layer_0': 256}. Best is trial 13 with value: 120.6114013671875.
# Early stopping at epoch 111, with best epoch being 76
# Early stopping at epoch 112, with best epoch being 26
# Early stopping at epoch 111, with best epoch being 31
# Early stopping at epoch 133, with best epoch being 25
# Early stopping at epoch 113, with best epoch being 25
# [I 2025-01-03 19:01:07,300] Trial 15 finished with value: 125.06859020233154 and parameters: {'learning_rate': 0.0001314324791069167, 'num_layers': 2, 'batch_size': 16, 'hidden_size_layer_0': 32, 'hidden_size_layer_1': 128}. Best is trial 13 with value: 120.6114013671875.
# Early stopping at epoch 112, with best epoch being 21
# Early stopping at epoch 111, with best epoch being 91
# Early stopping at epoch 114, with best epoch being 103
# Early stopping at epoch 113, with best epoch being 96
# Early stopping at epoch 111, with best epoch being 79
# [I 2025-01-03 19:03:51,846] Trial 16 finished with value: 125.5435082244873 and parameters: {'learning_rate': 4.8915591471056616e-05, 'num_layers': 2, 'batch_size': 16, 'hidden_size_layer_0': 16, 'hidden_size_layer_1': 128}. Best is trial 13 with value: 120.6114013671875.
# Early stopping at epoch 112, with best epoch being 84
# Early stopping at epoch 113, with best epoch being 5
# Early stopping at epoch 119, with best epoch being 27
# Early stopping at epoch 114, with best epoch being 28
# Early stopping at epoch 126, with best epoch being 7
# [I 2025-01-03 19:06:45,315] Trial 17 finished with value: 123.16494358062744 and parameters: {'learning_rate': 0.00041680766742831405, 'num_layers': 2, 'batch_size': 16, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 64}. Best is trial 13 with value: 120.6114013671875.
# Early stopping at epoch 117, with best epoch being 33
# Early stopping at epoch 149, with best epoch being 138
# Early stopping at epoch 165, with best epoch being 154
# Early stopping at epoch 165, with best epoch being 154
# Early stopping at epoch 123, with best epoch being 17
# [I 2025-01-03 19:10:08,594] Trial 18 finished with value: 118.09516185760499 and parameters: {'learning_rate': 0.00016002927684424158, 'num_layers': 1, 'batch_size': 16, 'hidden_size_layer_0': 256}. Best is trial 18 with value: 118.09516185760499.
# Early stopping at epoch 161, with best epoch being 150
# Early stopping at epoch 298, with best epoch being 287
# Early stopping at epoch 342, with best epoch being 331
# Early stopping at epoch 350, with best epoch being 339
# Early stopping at epoch 272, with best epoch being 261

# %%
from utils.utils import plot_preds_vs_truevalues
from utils.train_pipeline import get_preds_best_config

epochs_train_losses, epochs_val_losses, all_predictions, all_true_values = get_preds_best_config(study, pipeline, FFNN, model_type, model_params_keys, num_epochs =num_epochs, seed=seed, X=X, y=y, normalize_flags=NORMALIZE_FLAGS)

# Plot the train and validation losses for each fold
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
for i in range(5):
    axes[i].plot(epochs_train_losses[i], label="Train Loss")
    axes[i].plot(epochs_val_losses[i], label="Validation Loss")
    axes[i].set_title(f"Fold {i + 1}")
    axes[i].set_xlabel("Epoch")
    if i == 0:
        axes[i].set_ylabel("Loss")
    axes[i].legend()

plt.tight_layout()
plt.savefig(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
plt.show()

# # Plot the predictions vs true values for each fold
# # for fold in range(5):
# #     plot_preds_vs_truevalues(np.ravel(all_true_values[fold]), np.ravel(all_predictions[fold]), fold, save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))

# for fold in range(5):
#     img = mpimg.imread(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))
#     plt.figure(figsize=(10, 10))
#     plt.imshow(img)
#     plt.axis('off')  # Hide axes for a cleaner display
#     plt.show()
# Out:
# Best hyperparameters: {'learning_rate': 0.0003123987719070217, 'num_layers': 1, 'batch_size': 16, 'hidden_size_layer_0': 256}
# Early stopping at epoch 113, with best epoch being 77
# Early stopping at epoch 111, with best epoch being 93
# Early stopping at epoch 114, with best epoch being 83
# Early stopping at epoch 113, with best epoch being 91
# Early stopping at epoch 112, with best epoch being 91
# Validation Losses: [118.3537052154541, 103.70656824111938, 115.70962190628052, 132.367019367218, 113.30697231292724]
# Mean validation loss: 116.68877740859985
# Test Losses: [136.18596633911133, 120.11136322021484, 128.23906829833984, 121.70982738494872, 118.64235378265381]
# Mean test loss: 124.9777158050537

# %%
from models.ffnn_pytorch import FFNN
from utils.train_pipeline import EarlyStopper, ModelTrainingPipeline

n_trials = 100
num_epochs = 500
model_type = "FFNN"
model_name = "FFNNSeries_Masking"

suggestion_dict = {
    "learning_rate": {
        "type": "float",
        "args": [1e-5, 1e-3], 
        "kwargs": {"log": True} 
    },
    "num_layers": {
        "type": "categorical",
        "args": [[1, 2, 3, 4, 5]] 
    },        
    "batch_size": {
        "type": "categorical",
        "args": [[16, 32, 64, 128]] 
    }
}

model_params_keys = ["hidden_sizes_list"]


model_results_dir = os.path.join(RESULTS_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs")
os.makedirs(model_results_dir, exist_ok=True)  

#run_optuna_study(pipeline.run_cross_val, FFNN, model_type, suggestion_dict, model_params_keys, seed, [X_series, X_mask], y, [True, False], model_results_dir, n_trials=n_trials, num_epochs=num_epochs)

study = joblib.load(os.path.join(model_results_dir, "study.pkl"))
print_study_results(study)
plot_best_model_results(study.trials_dataframe(), save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
# Out:
# Number of finished trials:  100
# Best trial: 71
# Best hyperparameters: {'learning_rate': 0.0008635632912640252, 'num_layers': 4, 'batch_size': 16, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 256, 'hidden_size_layer_3': 128}
# Validation Losses: [2.381, 2.379, 3.284, 2.042, 2.445]
# Mean validation loss: 2.506
# Test Losses: [2.896, 3.812, 2.496, 3.221, 1.973]
# Mean test loss: 2.879
# Mean test MAE: 1.012 std: 0.084
# Mean test RMSE: 1.687 std: 0.186

# %%
from utils.utils import plot_preds_vs_truevalues
from utils.train_pipeline import get_preds_best_config


epochs_train_losses, epochs_val_losses, all_predictions, all_true_values = get_preds_best_config(study, pipeline, FFNN, model_type, model_params_keys, num_epochs =num_epochs, seed=seed, X= [X_series, X_mask], y=y, normalize_flags=[True, False])

# Plot the train and validation losses for each fold
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
for i in range(5):
    axes[i].plot(epochs_train_losses[i], label="Train Loss")
    axes[i].plot(epochs_val_losses[i], label="Validation Loss")
    axes[i].set_title(f"Fold {i + 1}")
    axes[i].set_xlabel("Epoch")
    if i == 0:
        axes[i].set_ylabel("Loss")
    axes[i].legend()

plt.tight_layout()
plt.savefig(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
plt.show()

# # Plot the predictions vs true values for each fold
# # for fold in range(5):
# #     plot_preds_vs_truevalues(np.ravel(all_true_values[fold]), np.ravel(all_predictions[fold]), fold, save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))


# for fold in range(5):
#     img = mpimg.imread(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))
#     plt.figure(figsize=(10, 10))
#     plt.imshow(img)
#     plt.axis('off')  # Hide axes for a cleaner display
#     plt.show()
# Out:
# Best hyperparameters: {'learning_rate': 0.0008635632912640252, 'num_layers': 4, 'batch_size': 16, 'hidden_size_layer_0': 256, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 256, 'hidden_size_layer_3': 128}
# Early stopping at epoch 116, with best epoch being 105
# Early stopping at epoch 111, with best epoch being 100
# Early stopping at epoch 117, with best epoch being 106
# Early stopping at epoch 138, with best epoch being 127
# Early stopping at epoch 134, with best epoch being 123
# Validation Losses: [2.380632162094116, 2.379382848739624, 3.2841126918792725, 2.042193651199341, 2.4454307556152344]
# Mean validation loss: 2.5063504219055175
# Test Losses: [2.895885944366455, 3.8119232654571533, 2.4956912994384766, 3.2206597328186035, 1.972725749015808]
# Mean test loss: 2.8793771982192995

# %%
from models.ffnn_pytorch import FFNN
from utils.utils import print_study_results, plot_best_model_results

n_trials = 100
num_epochs = 500
model_type = "FFNN"
model_name = "FFNNIndexes"

suggestion_dict = {
    "learning_rate": {
        "type": "float",
        "args": [1e-5, 1e-3], 
        "kwargs": {"log": True} 
    },
    "num_layers": {
        "type": "categorical",
        "args": [[1, 2, 3, 4]] 
    },        
    "batch_size": {
        "type": "categorical",
        "args": [[16, 32, 64, 128]] 
    }
}

model_params_keys = ["hidden_sizes_list"]


model_results_dir = os.path.join(RESULTS_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs")
os.makedirs(model_results_dir, exist_ok=True)  

#run_optuna_study(pipeline.run_cross_val, FFNN, model_type,suggestion_dict, model_params_keys, seed, [X_indices], y, [True], model_results_dir, n_trials=n_trials, num_epochs=num_epochs)

study = joblib.load(os.path.join(model_results_dir, "study.pkl"))
print_study_results(study)
plot_best_model_results(study.trials_dataframe(), save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
# Out:
# Number of finished trials:  100
# Best trial: 62
# Best hyperparameters: {'learning_rate': 0.0006379463628831539, 'num_layers': 4, 'batch_size': 16, 'hidden_size_layer_0': 32, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 128, 'hidden_size_layer_3': 256}
# Validation Losses: [0.051, 0.02, 0.016, 0.085, 0.052]
# Mean validation loss: 0.045
# Test Losses: [2.213, 5.819, 0.034, 0.46, 0.205]
# Mean test loss: 1.746
# Mean test MAE: 0.55 std: 0.299
# Mean test RMSE: 1.043 std: 0.812

# %%
from utils.utils import plot_preds_vs_truevalues
from utils.train_pipeline import get_preds_best_config

epochs_train_losses, epochs_val_losses, all_predictions, all_true_values = get_preds_best_config(study, pipeline, FFNN, model_type, model_params_keys, num_epochs =num_epochs, seed=seed, X=[X_indices], y=y, normalize_flags=[True])

# Plot the train and validation losses for each fold
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
for i in range(5):
    axes[i].plot(epochs_train_losses[i], label="Train Loss")
    axes[i].plot(epochs_val_losses[i], label="Validation Loss")
    axes[i].set_title(f"Fold {i + 1}")
    axes[i].set_xlabel("Epoch")
    if i == 0:
        axes[i].set_ylabel("Loss")
    axes[i].legend()

# plt.tight_layout()
# plt.savefig(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_losses.png"))
# plt.show()

# # Plot the predictions vs true values for each fold
# # for fold in range(5):
# #     plot_preds_vs_truevalues(np.ravel(all_true_values[fold]), np.ravel(all_predictions[fold]), fold, save_path=os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))


# for fold in range(5):
#     img = mpimg.imread(os.path.join(IMAGES_DIR, f"{model_name}_{n_trials}_trials_{num_epochs}_epochs_fold_{fold}_predictions.png"))
#     plt.figure(figsize=(10, 10))
#     plt.imshow(img)
#     plt.axis('off')  # Hide axes for a cleaner display
#     plt.show()
# Out:
# Best hyperparameters: {'learning_rate': 0.0006379463628831539, 'num_layers': 4, 'batch_size': 16, 'hidden_size_layer_0': 32, 'hidden_size_layer_1': 256, 'hidden_size_layer_2': 128, 'hidden_size_layer_3': 256}
# Early stopping at epoch 128, with best epoch being 117
# Early stopping at epoch 145, with best epoch being 134
# Early stopping at epoch 135, with best epoch being 124
# Early stopping at epoch 130, with best epoch being 119
# Early stopping at epoch 114, with best epoch being 103
# Validation Losses: [0.0510527566075325, 0.020463651046156883, 0.016171369701623917, 0.0850682184100151, 0.05199841409921646]
# Mean validation loss: 0.044950881972908974
# Test Losses: [2.2129483222961426, 5.818685054779053, 0.03368733823299408, 0.46009814739227295, 0.20461268723011017]
# Mean test loss: 1.7460063099861145
